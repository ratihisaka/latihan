# %%
import datetime as dt
print('Silahkan masukkan tanggal, bulan, dan tahun lahir Anda')
tanggal17 = int(input('Tanggal \t:'))
bulan17 = int(input('Bulan \t\t:'))
tahun17 = int(input('Tahun \t\t:'))

tanggal_lahir17 = dt.date(tahun17,bulan17,tanggal17)
print(f'Tanggal lahir Anda adalah: {tanggal_lahir17}')
print(f'Anda lahir pada hari {tanggal_lahir17:%A}')

hari_ini17 = dt.date.today()
print(f'Hari ini tanggal: {hari_ini17}')
umur17 = hari_ini17 - tanggal_lahir17
print(f'Umur anda adalah {umur17}')

# %%
import datetime as dt
print('Please enter your date, month and year of birth')
tanggal17 = int(input('Date \t:'))
bulan17 = int(input('Month \t:'))
tahun17 = int(input('Year \t:'))

tanggal_lahir17 = dt.date(tahun17,bulan17,tanggal17)
print(f'Your date of birth is {tanggal_lahir17}')
print(f'You were born on {tanggal_lahir17:%A}')

hari_ini17 = dt.date.today()
print(f'Today is {hari_ini17}')
umur17_hari = hari_ini17 - tanggal_lahir17
umur17_tahun = umur17_hari.days // 365
print(f'You are {umur17_tahun} years old')

# %%
soal_soal = {
    'Siapa leader BTS?' : 'A',
    'Siapa member tertua BTS?' : 'B',
    'Siapa nama asli SUGA BTS?' : 'A'
}

jawaban_jawaban = [['A. RM', 'B. Jimin', 'C. J-Hope'],
                  ['A. SUGA', 'B. Jin', 'C. JungKook'],
                  ['A. Min Yoongi', 'B. Jung Hoseok', 'C. Kim Taehyung']]
def mulai_game():
    tebakan_jawaban = []
    jawaban_benar = 0
    nomor_soal = 1
    
    for soal in soal_soal:
        print('------------------')
        print(soal)
        for jawaban in jawaban_jawaban[nomor_soal-1]:
            print(jawaban)
        tebakan = input('Masukkan (A,B,C) = ')
        tebakan = tebakan.upper()
        tebakan_jawaban.append(tebakan)
        jawaban_benar += check_jawaban(soal_soal.get(soal),tebakan)
        nomor_soal += 1
        
    menampilkan_score(jawaban_benar, tebakan_jawaban)
        
    
def check_jawaban(jawaban_benar,tebakan_user):
    if (jawaban_benar == tebakan_user):
        print('Yeayy Jawaban Anda Benar!!')
        return 1
    else:
        print('Yahhh jawaban Anda salah:( ')
        return 0
    
def menampilkan_score(score_benar, jawaban_saya):
    print('------------------')
    print('HASIL')
    print('------------------')
    print('Jawaban Saya : ',end='')
    for jawaban in jawaban_saya:
        print(jawaban, end=' ')
    print()
    
    score = score_benar / len(soal_soal)
    score *= 100
    print('Nilai Kamu : '+ str(int(score))+'%')
    print('BORAHAE<3')
def mulai_ulang():
    pass

mulai_game()
# Out:
# ------------------
# Siapa leader BTS?
# A. RM
# B. Jimin
# C. J-Hope
# Masukkan (A,B,C) =  A
# Yeayy Jawaban Anda Benar!!
# ------------------
# Siapa member tertua BTS?
# A. SUGA
# B. Jin
# C. JungKook
# Masukkan (A,B,C) =  B
# Yeayy Jawaban Anda Benar!!
# ------------------
# Siapa nama asli SUGA BTS?
# A. Min Yoongi
# B. Jung Hoseok
# C. Kim Taehyung
# Masukkan (A,B,C) =  A
# Yeayy Jawaban Anda Benar!!
# ------------------
# HASIL
# ------------------
# Jawaban Saya : A B A
# Nilai Kamu : 100%
# BORAHAE<3
