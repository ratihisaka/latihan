# %%
nama = input("Masukkan nama anda: ")
pekerjaan = input("Masukkan pekerjaan anda: ")
institusi = input("Masukkan institusi tempat anda bekerja: ")
print(f"{nama} adalah seorang {pekerjaan} di {institusi}.")
# Out:
# Masukkan nama anda:  ratih
# Masukkan pekerjaan anda:  mahasiswa
# Masukkan institusi tempat anda bekerja:  unud
# ratih adalah seorang mahasiswa di unud.

# %%
wish = "Semoga aku bisa ketemu bts"
print(wish[0:3])
# Out:
# Sem

# %%
wish = "Semoga aku bisa ketemu bts"
print(wish[0:-1])
# Out:
# Semoga aku bisa ketemu bt

# %%
wish = "Semoga aku bisa ketemu bts"
print(wish[2:-1:3])
# Out:
# makbaemb

# %%
wish = "Semoga aku bisa ketemu bts"
print(wish[0:-7])
# Out:
# Semoga aku bisa ket
