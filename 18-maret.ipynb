# %%
mahasiswa = 38
uang_di_dompet = 50000
print(mahasiswa)
print(uang_di_dompet)
print(mahasiswa*uang_di_dompet)

# %%
nama_depan = 'Dewa'
nama_tengah = ' '
nama_belakang = 'Ayu Ratih Isaka Putri'
print(nama_depan + nama_tengah + nama_belakang)
# Out:
# Dewa Ayu Ratih Isaka Putri

# %%
nim = '2308541017'
print(nim)
# Out:
# 2308541017

# %%
nama = input('Siapakah nama anda? ')
kegiatan = input('Apakah kegiatan anda sekarang, ' + nama +'? ')
print('Semangat '+ kegiatan +'nya yhh, ' + nama + '!')
# Out:
# Siapakah nama anda?  ratih
# Apakah kegiatan anda sekarang, ratih?  belajar python
# Semangat belajar pythonnya yhh, ratih!

# %%
uang_di_dompet = input('Berapakah jumlah uang di dompet anda? ')
uang_di_bank = input('Berapakah jumlah uang anda di Bank? ')
print('Total uang anda adalah Rp ' + uang_di_dompet + uang_di_bank)
# Out:
# Berapakah jumlah uang di dompet anda?  1000000000
# Berapakah jumlah uang anda di Bank?  1000000000000
# Total uang anda adalah Rp 10000000001000000000000

# %%
uang_di_dompet = input('Berapakah jumlah uang di dompet anda? ')
uang_di_bank = input('Berapakah jumlah uang anda di Bank? ')
total_uang = int(uang_di_dompet) + int(uang_di_bank)
print('Total uang anda adalah Rp '+ str(total_uang))
# Out:
# Berapakah jumlah uang di dompet anda?  1000000000
# Berapakah jumlah uang anda di Bank?  1000000000000
# Total uang anda adalah Rp 1001000000000
