# %%
bts = 7
seventeen = 13
print(bts > 5 and seventeen < 15)
# Out:
# True

# %%
print(bts < 5 or seventeen < 15)
# Out:
# True

# %%
print(bts < 5 or seventeen > 15)
# Out:
# False

# %%
print(not(bts < 5 or seventeen > 15))
# Out:
# True
