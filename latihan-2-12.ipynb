# %%
bts = ['kim namjoon','kim seokjin','min yoongi','jung hoseok','park jimin','kim taehyung','jeon jungkook']
print(bts)
# Out:
# ['kim namjoon', 'kim seokjin', 'min yoongi', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook']

# %%
print(bts[2])
print(bts[-3])
print(bts[0])
# Out:
# min yoongi
# park jimin
# kim namjoon

# %%
bts[0] = 'RM'
print(bts)
# Out:
# ['RM', 'kim seokjin', 'min yoongi', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook']

# %%
print(bts[2:-2])
# Out:
# ['min yoongi', 'jung hoseok', 'park jimin']

# %%
bts.append ('BTS')
print(bts)
# Out:
# ['RM', 'kim seokjin', 'min yoongi', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook', 'BTS']

# %%
bts.insert (3,'choi soobin')
print(bts)
# Out:
# ['RM', 'kim seokjin', 'min yoongi', 'choi soobin', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook', 'BTS']

# %%
bts.remove('choi soobin')
print(bts)
# Out:
# ['RM', 'kim seokjin', 'min yoongi', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook', 'BTS']

# %%
bts.remove('BTS')
print(bts)
# Out:
# ['RM', 'kim seokjin', 'min yoongi', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook']

# %%
bts[0] = 'kim namjoon'
print(bts)
# Out:
# ['kim namjoon', 'kim seokjin', 'min yoongi', 'jung hoseok', 'park jimin', 'kim taehyung', 'jeon jungkook']

# %%
for member in bts:
    print(member)
# Out:
# kim namjoon
# kim seokjin
# min yoongi
# jung hoseok
# park jimin
# kim taehyung
# jeon jungkook

# %%
print('jeon jungkook' in bts)
print('choi soobin' in bts)
# Out:
# True
# False
