# %%
data = [1,2,3,4,5,4,3,2,1]
terkecil = data[0]
for i in range(len(data)):
    if data[i] < terkecil:
        terkecil = data[i]
print(terkecil)
# Out:
# 1

# %%
data = [1,2,3,4,5,4,3,2,1]
terkecil = data[0]
for angka in data:
    if angka < terkecil:
        terkecil = angka
print(terkecil)
# Out:
# 1
