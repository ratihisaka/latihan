# %%
nama = input('Siapakah nama anda?')
uang_bulanan = input('Berapakah uang bulanan Anda? ')
uang_terpakai = input('Berapa uang yang sudah Anda pakai? ')
total_uang = int(uang_bulanan) - int(uang_terpakai)
print('Total uang ' + nama + ' saat ini adalah Rp'+ str(total_uang))
# Out:
# Siapakah nama anda? Ratih Isaka
# Berapakah uang bulanan Anda?  1500000
# Berapa uang yang sudah Anda pakai?  786000
# Total uang Ratih Isaka saat ini adalah Rp714000
