# %%
import datetime as dt
hari_ini17 = dt.date.today()
print(hari_ini17)
print(f"Hari ini adalah hari {hari_ini17:%A}")
tanggal17 = dt.date(2005,3,11)
print(tanggal17)
print(f"Hari itu adalah hari {tanggal17:%A}")
# Out:
# 2024-03-19
# Hari ini adalah hari Tuesday
# 2005-03-11
# Hari itu adalah hari Friday
