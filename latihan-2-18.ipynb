# %%
def full_nama(first_name,last_name):
    print(f"Nama lengkapnya adalah {first_name} {last_name}")

# %%
first_name = input("Nama depan anda adalah ")
last_name = input("Nama belakang anda adalah ")
full_nama(first_name,last_name)
# Out:
# Nama depan anda adalah  ratih
# Nama belakang anda adalah  isaka
# Nama lengkapnya adalah ratih isaka

# %%
angka = {
    "0" : "nol ",
    "1" : "satu ",
    "2" : "dua ",
    "3" : "tiga ",
    "4" : "empat ",
    "5" : "lima ",
    "6" : "enam ",
    "7" : "tujuh ",
    "8" : "delapan ",
    "9" : "sembilan "
}

# %%
nomor_HP = input("Masukkan nomor HP anda ")
nomor_angka = ""
for isi in nomor_HP:
    nomor_angka += angka.get(isi) +" "
    print(nomor_angka)
# Out:
# Masukkan nomor HP anda  081999051667
# nol
# nol  delapan
# nol  delapan  satu
# nol  delapan  satu  sembilan
# nol  delapan  satu  sembilan  sembilan
# nol  delapan  satu  sembilan  sembilan  sembilan
# nol  delapan  satu  sembilan  sembilan  sembilan  nol
# nol  delapan  satu  sembilan  sembilan  sembilan  nol  lima
# nol  delapan  satu  sembilan  sembilan  sembilan  nol  lima  satu
# nol  delapan  satu  sembilan  sembilan  sembilan  nol  lima  satu  enam
# nol  delapan  satu  sembilan  sembilan  sembilan  nol  lima  satu  enam  enam
# nol  delapan  satu  sembilan  sembilan  sembilan  nol  lima  satu  enam  enam  tujuh
