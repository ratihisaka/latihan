# %%
nilai = float(input('Nilai anda adalah '))
if nilai >=80:
    print('Anda mendapatkan nilai A')
    print('Bagus sekali, selamat!')
elif nilai >= 70:
    print('Anda mendapatkan nilai B')
    print('Tingkatkan prestasimu!')
elif nilai >= 60:
    print('Anda mendapatkan nilai C')
    print('Lain kali harus lebih baik!')
elif nilai >= 50:
    print('Anda mendapatkan nilai D')
    print('Ulang lagi tahun depan yaa')
else:
    print('Anda mendapatkan nilai E')
    print('Sampai jumpa tahun depan yhh')
# Out:
# Nilai anda adalah  98
# Anda mendapatkan nilai A
# Bagus sekali, selamat!

# %%
nilai = float(input('Nilai anda adalah '))
if nilai >=80:
    print('Anda mendapatkan nilai A')
    print('Bagus sekali, selamat!')
if nilai < 80 and nilai >= 70:
    print('Anda mendapatkan nilai B')
    print('Tingkatkan prestasimu!')
if nilai < 70 and nilai >= 60:
    print('Anda mendapatkan nilai C')
    print('Lain kali harus lebih baik!')
if nilai >= 50 and nilai < 60:
    print('Anda mendapatkan nilai D')
    print('Ulang lagi tahun depan yaa')
if nilai < 50:
    print('Anda mendapatkan nilai E')
    print('Sampai jumpa tahun depan yhh')
# Out:
# Nilai anda adalah  32
# Anda mendapatkan nilai E
# Sampai jumpa tahun depan yhh

# %%
a = 0
while a < 8:
    print('Angka '+ str(a)+' masih dibawah 8')
    a += 1
# Out:
# Angka 0 masih dibawah 8
# Angka 1 masih dibawah 8
# Angka 2 masih dibawah 8
# Angka 3 masih dibawah 8
# Angka 4 masih dibawah 8
# Angka 5 masih dibawah 8
# Angka 6 masih dibawah 8
# Angka 7 masih dibawah 8

# %%
a = 0
if a < 8:
    print('Angka '+ str(a)+' masih dibawah 8')
    a += 1
# Out:
# Angka 0 masih dibawah 8

# %%
a = 0
b = 17
while a < 8:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a += 1
    b -= 1
    
a = 8
b = 9
while a > 0:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a -= 1
    b += 1
# Out:
#
# $               $
# $$             $$
# $$$           $$$
# $$$$         $$$$
# $$$$$       $$$$$
# $$$$$$     $$$$$$
# $$$$$$$   $$$$$$$
# $$$$$$$$ $$$$$$$$
# $$$$$$$   $$$$$$$
# $$$$$$     $$$$$$
# $$$$$       $$$$$
# $$$$         $$$$
# $$$           $$$
# $$             $$
# $               $

# %%
a = 0
b = 10
while a < 8:
    print(b * ' ' + a * '$' + '  ' + a * '$')
    a += 1
    b -= 1
    
a = 8
b = 2
while a > 0:
    print(b * ' ' + a * '$' + '  ' + a * '$')
    a -= 1
    b += 1
# Out:
#
#          $  $
#         $$  $$
#        $$$  $$$
#       $$$$  $$$$
#      $$$$$  $$$$$
#     $$$$$$  $$$$$$
#    $$$$$$$  $$$$$$$
#   $$$$$$$$  $$$$$$$$
#    $$$$$$$  $$$$$$$
#     $$$$$$  $$$$$$
#      $$$$$  $$$$$
#       $$$$  $$$$
#        $$$  $$$
#         $$  $$
#          $  $

# %%
a = 8
b = 9
while a > 0:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a -= 1
    b += 1
    
a = 0
b = 17
while a < 8:
    print(a * '$' + (b-a) * ' ' + a * '$')
    a += 1
    b -= 1
# Out:
# $$$$$$$$ $$$$$$$$
# $$$$$$$   $$$$$$$
# $$$$$$     $$$$$$
# $$$$$       $$$$$
# $$$$         $$$$
# $$$           $$$
# $$             $$
# $               $
#
# $               $
# $$             $$
# $$$           $$$
# $$$$         $$$$
# $$$$$       $$$$$
# $$$$$$     $$$$$$
# $$$$$$$   $$$$$$$

# %%
a = 0
b = 10
while a < 8:
    print(b * ' ' + a * '$' + a * '$')
    a += 1
    b -= 1
    
a = 0
while a < 6:
    print('   '+'$$$$$$$$$$$$$$')
    a += 1
# Out:
#
#          $$
#         $$$$
#        $$$$$$
#       $$$$$$$$
#      $$$$$$$$$$
#     $$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$
#    $$$$$$$$$$$$$$

# %%
a = 9
b = 0
while a > 0:
    print('$' + b * ' ' + '$')
    a -= 1
    b += 1
    
a = 0
b = 7
while a < 8:
    print('$' + b * ' ' + '$')
    a += 1
    b -= 1
# Out:
# $$
# $ $
# $  $
# $   $
# $    $
# $     $
# $      $
# $       $
# $        $
# $       $
# $      $
# $     $
# $    $
# $   $
# $  $
# $ $
# $$
