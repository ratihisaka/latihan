# %%
judul = "Matematika Ilmu Yang Menyenangkan"
print(len(judul))
judul.upper()
# Out:
# 33
# 'MATEMATIKA ILMU YANG MENYENANGKAN'

# %%
judul = "Matematika Ilmu Yang Menyenangkan"
print(len(judul))
judul.lower()
# Out:
# 33
# 'matematika ilmu yang menyenangkan'

# %%
judul = "Matematika Ilmu Yang Menyenangkan"
print(len(judul))
judul.find('Yang')
# Out:
# 33
# 16

# %%
judul = "Matematika Ilmu Yang Menyenangkan"
print(len(judul))
judul.replace('Menyenangkan', 'Bikin Pusing')
# Out:
# 33
# 'Matematika Ilmu Yang Bikin Pusing'

# %%
judul = "Matematika Ilmu Yang Menyenangkan"
print(len(judul))
print('ilmu' in judul)
# Out:
# 33
# False
