# %%
x = 5 > 3
print(x)
x = 3 < 5
print(x)
x = 5 >= 3
print(x)
x = 3 <= 5
print(x)
x = 5 == 5
print(x)
x = 5 != 3
print(x)
# Out:
# True
# True
# True
# True
# True
# True

# %%
x = 3 > 5
print(x)
x = 5 < 3
print(x)
x = 3 >= 5
print(x)
x = 5 <= 3
print(x)
x = 5 == 3
print(x)
x = 5 != 5
print(x)
# Out:
# False
# False
# False
# False
# False
# False
