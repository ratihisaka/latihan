# %%
bts = ['namjoon', 'jin', 'yoongi', 'jhope', 'jimin', 'v' , 'jk']
for jenis in bts:
    print(jenis)
# Out:
# namjoon
# jin
# yoongi
# jhope
# jimin
# v
# jk

# %%
i = 0
while i < len(bts):
    print(bts[i])
    i+=1
# Out:
# namjoon
# jin
# yoongi
# jhope
# jimin
# v
# jk
