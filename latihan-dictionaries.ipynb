# %%
data_orang = {
    'nama' : 'Ratih Isaka',
    'umur' : 19,
    'apakah_single' : False
}

# %%
print(data_orang['nama'])
# Out:
# Ratih Isaka

# %%
print(data_orang['Nama'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(data_orang['Nama'])
#
# KeyError: 'Nama'

# %%
print(data_orang.get('nama'))
# Out:
# Ratih Isaka

# %%
print(data_orang.get('Nama'))
# Out:
# None

# %%
print(data_orang.get('tanggal_lahir'))
# Out:
# None

# %%
print(data_orang.get('tanggal_lahir', '11-3-2005'))
# Out:
# 11-3-2005

# %%
print(data_orang)
# Out:
# {'nama': 'Ratih Isaka', 'umur': 19, 'apakah_single': False}

# %%
data_orang['HP'] = '081999051667'

# %%
print(data_orang['HP'])
# Out:
# 081999051667

# %%
print(data_orang)
# Out:
# {'nama': 'Ratih Isaka', 'umur': 19, 'apakah_single': False, 'HP': '081999051667'}
