# %%
tinggi = float(input('Berapakah tinggi anda? '))
cm_atau_inci = input('Tinnginya dalam cm atau inci? ')

if cm_atau_inci.upper() == 'CM':
    tinggi = tinggi*0.393701
    print('Tinggi anda adalah '+ str(tinggi) + 'inci')
elif cm_atau_inci.upper() == 'INCI':
    tinggi = tinggi/0.393701
    print(f'Tinggi anda adalah {tinggi} cm')
# Out:
# Berapakah tinggi anda?  167
# Tinnginya dalam cm atau inci?  cm
# Tinggi anda adalah 65.748067inci

# %%
tinggi = float(input('Berapakah tinggi anda? '))
cm_atau_inci = input('Tinnginya dalam cm atau inci? ')

if cm_atau_inci.upper() == 'CM':
    tinggi = tinggi*0.393701
    print('Tinggi anda adalah '+ str(tinggi) + 'inci')
elif cm_atau_inci.upper() == 'INCI':
    tinggi = tinggi/0.393701
    print(f'Tinggi anda adalah {tinggi} cm')
# Out:
# Berapakah tinggi anda?  65.748067
# Tinnginya dalam cm atau inci?  inci
# Tinggi anda adalah 167.0 cm
